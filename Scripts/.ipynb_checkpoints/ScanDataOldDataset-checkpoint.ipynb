# %%
import numpy as np
import os
import sys
import re
import glob
import h5py 
import random
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D,axes3d

# %%
# check what is in the dataset
dataset_base = "/nfshome/mliu/Triforce_CaloML/Output/regression_fixedangle_pi0_test/"
el_path = os.path.join(dataset_base,'results.h5')
elf = h5py.File(el_path,'r')
print(elf)
for key in elf.keys():
    print(key)
    print(np.array(elf[key]))
plt.scatter(elf['regressor_pred'], elf['regressor_true'], color='g', alpha = 0.5)
# %matplotlib inline
# Out:
# <HDF5 file "results.h5" (mode r)>
# regressor_loss_history_test
# []
# regressor_loss_history_train
# [ 19464.40714111   1296.64030762   1758.74494476    935.76260986
#     523.86891632    347.69727478    351.85696106]
# regressor_pred
# [ 467.36035156  387.19259644  150.34947205 ...,  302.05596924  450.78265381
#   129.97828674]
# regressor_true
# [ 483.6529541   390.81716919  157.14068604 ...,  319.81207275  434.57141113
#   143.71507263]

# %%
#quickly visulize data
#randomly pick a event
#visulize the event
hcalarray = np.array(elf['ECAL'])
#hcalenergy =np.array(elf['HCAL_E'])
#ecalenergy =np.array(elf['ECAL_E'])
ecalenergy = elf['ECAL'].value.sum( axis = (1,2,3))
hcalenergy = elf['HCAL'].value.sum( axis = (1,2,3))

# %%
sample= random.sample(list(hcalarray),1)[0]
print(sample.size,sample.shape)
xy = np.mgrid[0:51:1,0:51:1,0:25:1].reshape(3,-1).T
viz = [[x,y,z,sample[x][y][z]] for  (x,y,z) in list(xy) if sample[x][y][z]>0]
#viz = [ for item in vizall]
#print(filter(lambda x: x[3]>0, vizall))
vizx = [item[0] for item in viz]
vizy = [item[1] for item in viz]
vizz = [item[2] for item in viz]
vize = [item[3]*100 for item in viz]
# Out:
# 15625 (25, 25, 25)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-4527d4e0301f> in <module>()
#       2 print(sample.size,sample.shape)
#       3 xy = np.mgrid[0:51:1,0:51:1,0:25:1].reshape(3,-1).T
# ----> 4 viz = [[x,y,z,sample[x][y][z]] for  (x,y,z) in list(xy) if sample[x][y][z]>0]
#       5 #viz = [ for item in vizall]
#       6 #print(filter(lambda x: x[3]>0, vizall))
#
# <ipython-input-16-4527d4e0301f> in <listcomp>(.0)
#       2 print(sample.size,sample.shape)
#       3 xy = np.mgrid[0:51:1,0:51:1,0:25:1].reshape(3,-1).T
# ----> 4 viz = [[x,y,z,sample[x][y][z]] for  (x,y,z) in list(xy) if sample[x][y][z]>0]
#       5 #viz = [ for item in vizall]
#       6 #print(filter(lambda x: x[3]>0, vizall))
#
# IndexError: index 25 is out of bounds for axis 0 with size 25

# %%
# %matplotlib inline
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vizx,vizy,vizz,c=vize,s= vize ,marker='o',alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-13236c7eb31a> in <module>()
#       4 fig = plt.figure(figsize=(12,12))
#       5 ax = fig.add_subplot(111, projection='3d')
# ----> 6 ax.scatter(vizx,vizy,vizz,c=vize,s= vize ,marker='o',alpha=0.5)
#
# NameError: name 'vizx' is not defined

# %%
import seaborn as sns
trueenergy =np.array(elf['target'][:,1])
recoenergy = hcalenergy + ecalenergy
fig = plt.figure(figsize=(5,5))
print(recoenergy)
df=pd.DataFrame({'true energy [GeV]': trueenergy, 'HCAL_E+ECAL_E [GeV]': recoenergy*50})
#ax.scatter(recoenergy,trueenergy,c=vize,s= vize ,marker='o',alpha=0.5)
#plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')
sns.regplot(x=df["true energy [GeV]"], y=df["HCAL_E+ECAL_E [GeV]"], line_kws={"color":"r","alpha":0.7,"lw":5})
# Out:
# [ 9.06659285  5.4568376   0.63519817 ...,  1.43259418  8.3667054
#   3.89315149]

# %%
trueenergy =np.array(elf['target'])[:,1]
recoenergy = hcalenergy*50 + ecalenergy*50
fig = plt.figure(figsize=(5,5))
df=pd.DataFrame({'true energy [GeV]': trueenergy, 'HCAL_E+ECAL_E [GeV]': (recoenergy-trueenergy)/trueenergy})
#ax.scatter(recoenergy,trueenergy,c=vize,s= vize ,marker='o',alpha=0.5)
#plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')
sns.regplot(x=df["true energy [GeV]"], y=df["HCAL_E+ECAL_E [GeV]"], line_kws={"color":"r","alpha":0.7,"lw":5})
