# %%
import sys,os
if __package__ is None:
    sys.path.append(os.path.realpath("/data/shared/CMS_Deep_Learning"))
    sys.path.append(os.path.realpath("/data/shared/RegressionLCD"))
    sys.path.append(os.path.realpath("/nfshome/mliu/LCDstudies/Scripts"))
# %matplotlib inline
from regression_anautils import *
# load true/false values
nbins = 10
gammaf = h5py.File('/bigdata/shared/LCDLargeWindow/fixedangle/GammaEscan/GammaEscan_1_1.h5','r')
gamma_true = np.array(gammaf['energy'])
gamma_pred = np.array(gammaf['HCAL_E'])+np.array(gammaf['ECAL_E'])

binning = 10
gamma_data = {'true':gamma_true,'pred':gamma_pred,'binning':binning,'fitline':True,'label':'gamma','style':'*','color':'green'}
dps = []
dps.append(gamma_data)
plot_eres_v1(dps)
# Out:
# [{'pred': array([  75.11346189,  309.25591455,  288.56509305, ...,  105.33234297,
#         459.58783826,  353.08480349]), 'label': 'gamma', 'binning': 10, 'true': array([  88.85477 ,  346.539652,  327.863178, ...,   99.232065,
#         458.762363,  374.167299]), 'color': 'green', 'fitline': True, 'style': '*'}]
